# %%
require 'narray'
require 'daru'
include Daru

require_relative 'table.rb'
nil
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min\",\"downloadable\":\"http://cdn.rawgit.com/domitry/d3-downloadable/master/d3-downloadable\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"downloadable\":{\"exports\":\"downloadable\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');require(['downloadable'], function(downloadable){window['downloadable']=downloadable;console.log('finished loading downloadable');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"http://cdn.rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    w
# ...

# %%
table = Table.new('../data/20160707_table.csv')
table.df.vectors= Index.new(table.df.vectors.map{|i| i.to_sym})
table.df.head
nil

# %%
#table.retrieve_background('../data/20160707_nox.csv', :nox)
#table.df.head

# %%
#table.retrieve_background('../data/20160701_co2.csv', :co2)
#table.df.head

# %%
#table.duration.head

# %%
table.associate_background('../data/20160707_background.csv', 50, 15)
table.df.head
# Out:
# #<Daru::DataFrame(10x28)>
#                 id_fan country_fa         id    country     remark      start       stop  img_start   img_stop dslr_start  dslr_stop       date       euro   euro_est         tz       bran   add_info   blue_lid       side    startdt     stopdt        nox        co2   duration nox_backgr co2_backgr   nox_corr   co2_corr
#           0  BM-211-XW          F  DC 510 ZD          F Bis 12220    08:31:18   08:33:43    8310101    8330131   IMG_5666   IMG_5669 07.07.2016        nil        nil        utc      Volvo        500          x     rechts 2016-07-07 2016-07-07 211.505675 542.304320        145 84.2554009 470.947574 127.250274 71.3567460
#           1  KH-PH-650          D  KM TC 923          D blauer Dec   08:35:16   08:36:54    8350146    8370175   IMG_5670   IMG_5674 07.07.2016        nil        nil        utc   Mercedes       1844        nil        nil 2016-07-07 2016-07-07 459.772600 546.357694         98 84.2554009 470.947574 375.517199 75.4101200
# ...

# %%
table.compute_correction
table.df.head
# Out:
# RuntimeError: Background too high at row Z BU 5028.
# /home/tim/Studium/HiWi/LKW/bin/table.rb:63:in `block in compute_correction'
# /home/tim/.rvm/gems/ruby-2.3.1@nox/gems/daru-0.1.4.1/lib/daru/dataframe.rb:802:in `block in map_rows!'
# /home/tim/.rvm/gems/ruby-2.3.1@nox/gems/daru-0.1.4.1/lib/daru/index.rb:42:in `each_key'
# /home/tim/.rvm/gems/ruby-2.3.1@nox/gems/daru-0.1.4.1/lib/daru/index.rb:42:in `each'
# /home/tim/.rvm/gems/ruby-2.3.1@nox/gems/daru-0.1.4.1/lib/daru/dataframe.rb:801:in `map_rows!'
# /home/tim/Studium/HiWi/LKW/bin/table.rb:58:in `compute_correction'
# (pry):32:in `<main>'
# /home/tim/.rvm/gems/ruby-2.3.1@nox/gems/pry-0.10.4/lib/pry/pry_instance.rb:355:in `eval'
# /home/tim/.rvm/gems/ruby-2.3.1@nox/gems/pry-0.10.4/lib/pry/pry_instance.rb:355:in `evaluate_ruby'
# /home/tim/.rvm/gems/ruby-2.3.1@nox/gems/pry-0.10.4/lib/pry/pry_instance.rb:323:in `handle_line'
# ...

# %%
table.save('../data/20160707_table.csv')
